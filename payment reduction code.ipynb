# %%
class student :
  def __init__(name,uid,c,cost):
    student_name=name
    unique_id=uid
    balance=c - cost

class owner :
  def __init__(name,uid,cost):
    student_name=name
    gitam_wallet_id=uid
    unique_id="UX123"
    balance=1000 + cost

# %%
import uuid
users=[]
transactions=[]
def get_uuid():
  return uuid.uuid4()
# id,name,username,emailId,phone_number,balance,nfc_id
class User:
  def __init__(self,name,username,emailid,phone_number,balance):
    self.id=get_uuid()
    self.name=name
    self.username=username
    self.emailid=emailid
    self.phone_number=phone_number
    self.balance=balance
    self.nfc_id=get_uuid()
    self.transaction=[]
def make_transaction(self,transaction):
  source_user=next(usr for usr in users if usr.id==transaction.source_user.id)
  if not source_user:
    raise Exception('source user not found')
  destination_user=next(usr for usr in users if usr.id==transaction.destination_user.id)
  if not destination_user:
    raise Exception('destination user not found')

  if source_user.balance<transaction.amount:
    raise Exception('low balance')

  if source_user.id==self.id:
    self.balance=self.balance-transaction.amount
  else:
    self.balance=self.balance+transaction.amount
  transaction.status='AC'
  transactions.push(transaction)


# id,tag,source,destination,status,nfc_id,amount
class Transaction:
  def __init__(self,tag,source,destination,nfc_id,amount):
    if(amount<=0):
      raise Exception("Invalid amount requested")
    self.id=get_uuid()
    self.tag=tag
    self.source=source
    self.destination=destination
    # self.status=status
    self.nfc_id=nfc_id
    self.amount=amount

# %%
userr=User("a",123,"120@gitam.in",98899,1000)
userr=User("b",124,"121@gitam.in",99459,2000)
userr=User("c",125,"127@gitam.in",99329,1500)
userr=User("d",126,"126@gitam.in",99129,1760)

tran=Transaction(1,"a","b",123,3)
# Out:
# ['a', 'a', 'b', <__main__.User object at 0x7fde7b6ee550>, <__main__.User object at 0x7fde7b6eed90>, <__main__.User object at 0x7fde7b6ee460>, <__main__.User object at 0x7fde7b6eefa0>, <__main__.User object at 0x7fde7b8039a0>, <__main__.User object at 0x7fde7b803550>, <__main__.User object at 0x7fde7b803790>, <__main__.User object at 0x7fde7b803d00>]
# ['a', 'a', 'b', <__main__.User object at 0x7fde7b6ee550>, <__main__.User object at 0x7fde7b6eed90>, <__main__.User object at 0x7fde7b6ee460>, <__main__.User object at 0x7fde7b6eefa0>, <__main__.User object at 0x7fde7b8039a0>, <__main__.User object at 0x7fde7b803550>, <__main__.User object at 0x7fde7b803790>, <__main__.User object at 0x7fde7b803d00>, <__main__.User object at 0x7fde7b869e50>, <__main__.User object at 0x7fde7b869490>, <__main__.User object at 0x7fde7b8695b0>, <__main__.User object at 0x7fde7b748550>]
